# %% [markdown]
# # Main assignment 01 - Notebook files, python recap, theory

# %%
import sys

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=13, micro=7, releaselevel='final', serial=0)
