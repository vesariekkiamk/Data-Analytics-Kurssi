# %%
import statistics
import math

# %%
Dictionary = {"Discrete":[1, 2, 3, 4], "Continuous":[12.5, 16.0, 20.2, 30.4], "Nominal":["man", "woman", "child", "animal", "animal"], "Ordinal":["yes", "no", "maybe", "no opinion"]}

# %%
statistics.mode(Dictionary["Nominal"])
# Out:
# 'animal'

# %%
statistics.mode(Dictionary["Ordinal"])
# Out:
# 'yes'

# %% [markdown]
# "yes" tulee sen takia ylemmässä koodissa, koska ei ole eniten toistuvaa dataa niin koodi ottaa ensimmäinen arvon jonka se saa.

# %%
statistics.mean(Dictionary["Continuous"])
# Out:
# 19.775

# %%
statistics.mean(Dictionary["Discrete"])
# Out:
# 2.5

# %%
arvo = statistics.mean(Dictionary["Discrete"])

if arvo <= (2.4):
    print("liian pieni arvo")
else:
    print("iso arvo")
# Out:
# iso arvo

# %% [markdown]
# Importtasin kirjastot ja käytin niiden kahta erillaista ominaisuutta löytääkseni eri data-arvoja.

# %% [markdown]
# Lopuksi testailin pieniä omia ajatuksia arvoista.
