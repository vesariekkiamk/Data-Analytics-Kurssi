# %% [markdown]
# # Section 1

# %%
world = "World"
world
# Out:
# 'World'

# %% [markdown]
# #### Section 1 kohdalla asensin venvin, asensin tarvittavat lisäosat ja tein git-repon.

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# ### Main assignment 01 - Notebook files, python recap, theory

# %%
import sys

# %%
sys.version_info
# Out:
# sys.version_info(major=3, minor=13, micro=7, releaselevel='final', serial=0)

# %% [markdown]
# #### Testasin venvin toimintaa ja kirjasin markdownilla tehtävän nimen.

# %% [markdown]
# ---

# %% [markdown]
# # Section 3

# %%
Dictionary = {"Discrete":[1, 2, 3, 4], "Continuous":[12.5, 16.0, 20.2, 30.4], "Nominal":["man", "woman", "child", "animal"], "Ordinal":["yes", "no", "maybe", "no opinion"]}

# %% [markdown]
# ### Testaan .get toimintoa.

# %%
print(Dictionary.get("Discrete"))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### Lopuksi kokeilen omaa koodia joka hakee tietyn datan listasta ja printtaa tekstin sen perusteella.

# %%
print(Dictionary.get("Nominal"))

if "plane" in Dictionary["Nominal"]:
    print("found")
else:
    print("not found")

if "man" in Dictionary["Nominal"]:
    print("found")
else:
    print("not found")
# Out:
# ['man', 'woman', 'child', 'animal']
# not found
# found

# %% [markdown]
# ---

# %% [markdown]
# # Section 4

# %% [markdown]
# ## Lisätään kirjastot.

# %%
import statistics
import math

# %% [markdown]
# #### Lisätään Section 3 kohdasta Dictioary ja lisätään "Nominaliin" yksi toistuva data merkintä.

# %%
Dictionary = {"Discrete":[1, 2, 3, 4], "Continuous":[12.5, 16.0, 20.2, 30.4], "Nominal":["man", "woman", "child", "animal", "animal"], "Ordinal":["yes", "no", "maybe", "no opinion"]}

# %% [markdown]
# #### Testataan statistic.modea joka hakee eniten toistuvan datan.

# %%
statistics.mode(Dictionary["Nominal"])
# Out:
# 'animal'

# %%
statistics.mode(Dictionary["Ordinal"])
# Out:
# 'yes'

# %% [markdown]
# #### "yes" merkintä tulee sen takia ylemmässä koodissa, koska ei ole eniten toistuvaa dataa niin koodi ottaa ensimmäinen arvon jonka se saa.

# %% [markdown]
# ## Seuraavaksi kokeillaan statistic.mean komentoa joka hakee keskiarvon.

# %%
statistics.mean(Dictionary["Continuous"])
# Out:
# 19.775

# %%
statistics.mean(Dictionary["Discrete"])
# Out:
# 2.5

# %% [markdown]
# ##### Tässä kohtaa testaillaan koodilla huvikseen taas eri print vaihtoehtoja tuloksien mukaan.

# %%
arvo = statistics.mean(Dictionary["Discrete"])

if arvo <= (2.4):
    print("liian pieni arvo")
else:
    print("iso arvo")
# Out:
# iso arvo

# %% [markdown]
# ---

# %% [markdown]
# # Section 5
