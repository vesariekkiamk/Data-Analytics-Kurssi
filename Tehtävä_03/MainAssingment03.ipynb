# %% [markdown]
# # TEHTÄVÄ 3 ON MYÖHÄINEN PALAUTUS

# %% [markdown]
# ---

# %% [markdown]
# ## Main Assignment 3 Visuals

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %% [markdown]
# ---

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Laitetaan kaikki csv tiedostot omiin dataframeihin ja globilla kerrotaan pythonille etsiä kaikki .csv tiedostot kansiosta ja palauttaa ne listana.

# %%
df1 = pd.read_csv('Kunta.csv')
df2 = pd.read_csv('majoituskapasiteetti.csv')
df3 = pd.read_csv('teidenpituuskunnittain.csv')
glob.glob('*.csv')
# Out:
# ['kaikkidataRaportti.csv',
#  'Kunta.csv',
#  'majoituskapasiteetti.csv',
#  'teidenpituuskunnittain.csv']

# %% [markdown]
# ### Concatilaa yhdistetään kaikki dataframet ja sitten luodaan niistä yksittäinen .csv tiedosto.

# %%
kaikkidata = pd.concat([df1, df2, df3], ignore_index=True)
kaikkidata.to_csv('kaikkidataRaportti.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Task 2

# %% [markdown]
# ---

# %% [markdown]
# ## Task 3

# %% [markdown]
# ---

# %% [markdown]
# ## Task 4

# %% [markdown]
# ---
